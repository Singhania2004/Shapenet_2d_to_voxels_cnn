# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

import torch
from src.utils.voxel_to_mesh import voxel_to_mesh, save_mesh

# %%
# Fake voxel output
voxel = torch.rand(1, 32, 32, 32).numpy()

mesh = voxel_to_mesh(voxel)

save_mesh(mesh, "test.obj")

print("Saved test.obj")
# Out:
# Saved test.obj
