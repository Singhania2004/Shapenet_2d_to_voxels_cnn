# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.utils.config import load_config
from src.data.dataloader import get_dataloader

config = load_config("../configs/config.yaml")
dataloader = get_dataloader(config)

images, voxels = next(iter(dataloader))

print("Image shape:", images.shape)
print("Voxel shape:", voxels.shape)
# Out:
# Image shape: torch.Size([16, 3, 128, 128])
# Voxel shape: torch.Size([16, 1, 32, 32, 32])

# %%
import matplotlib.pyplot as plt

# Show first image
img = images[0].permute(1, 2, 0).numpy()

plt.imshow(img)
plt.title("Sample Input Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))

# %%
voxel = voxels[0][0].numpy()

# Show middle slice
slice_idx = voxel.shape[0] // 2

plt.imshow(voxel[slice_idx])
plt.title("Voxel Slice")
plt.colorbar()
